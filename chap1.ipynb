# %%
a=3  #將3這個值丟入a
b=5  #將5這個值丟入a
a+b  #把a跟b兩者相加
# Out:
# 8

# %%
import requests 
a=requests.get("https://www.Facebook.com")#要求獲取此網站的程式碼
print(a.text) #以文字的方式呈現
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant" id="facebook" class="no_js">
# ...
